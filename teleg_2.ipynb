# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_excel(r'C:\Users\Julaysa\Desktop\Telegram\2.xlsx')
data.head(5)
# Out:
#      МеткаВремени        ДатаСообщения  ИдКонтакта  \
# 0  63782900000000  2022-03-14T18:44:38   875413210
# 1  63782900000000  2022-03-14T18:44:41   875413210
# 2  63782900000000  2022-03-14T18:45:34   875413210
# 3  63782900000000  2022-03-14T18:45:34   875413210
# 4  63782900000000  2022-03-14T18:45:35   875413210
#
#                                       ТекстСообщения  ИдСообщения  \
# 0                                                123       1103.0
# 1                                             Отмена       1105.0
# 2  С помощью кнопок под этим сообщением выберите ...       1096.0
# 3  С помощью кнопок под этим сообщением выберите ...       1096.0
# 4  С помощью кнопок под этим сообщением выберите ...       1096.0
#
#       ИдСобытия     ДанныеКнопки  \
# 0           NaN              NaN
# 1           NaN              NaN
# 2  3.759870e+18  /inline_event 1
# 3  3.759870e+18  /inline_event 1
# 4  3.759870e+18  /inline_event 1
#
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120690 entries, 0 to 120689
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   МеткаВремени       120690 non-null  int64
#  1   ДатаСообщения      120690 non-null  object
#  2   ИдКонтакта         120690 non-null  int64
#  3   ТекстСообщения     118863 non-null  object
#  4   ИдСообщения        119508 non-null  float64
#  5   ИдСобытия          32073 non-null   float64
#  6   ДанныеКнопки       32073 non-null   object
#  7   КнопкиСообщения    31442 non-null   object
#  8   ИзменениеПодписки  1181 non-null    float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 8.3+ MB

# %%
data['ИзменениеПодписки'].unique()
# Out:
# array([nan, -1.,  1.])

# %%
data_key=data['КнопкиСообщения']

# %%
len(data_key)
# Out:
# 120690

# %%
data_key=list(np.array(data_key))
type(data_key)
# Out:
# list

# %%
rows='text":"'
key=[]
for r in data_key:
    if str(r)=='nan':
        key.append('Не нажимали')
    elif str(r)!='nan':
        for i in range(len(str(r))):
            if r[i]=='t':
                if r[i:i+7]==rows:
                    line=line+r[i+7:r.index('"',i+7)]+';'
        key.append(line)
    line=''

# %%
key[:10]
# Out:
# ['Не нажимали',
#  'Не нажимали',
#  'Мероприятия для бухгалтера;Мероприятия для юриста;',
#  'Мероприятия для бухгалтера;Мероприятия для юриста;',
#  'Мероприятия для бухгалтера;Мероприятия для юриста;',
#  'Мероприятия для бухгалтера;Мероприятия для юриста;',
#  'Мероприятия для бухгалтера;Мероприятия для юриста;',
#  'Мероприятия для бухгалтера;Мероприятия для юриста;',
#  'Не нажимали',
#  'Не нажимали']

# %%
data.head(10)
# Out:
#      МеткаВремени        ДатаСообщения  ИдКонтакта  \
# 0  63782900000000  2022-03-14T18:44:38   875413210
# 1  63782900000000  2022-03-14T18:44:41   875413210
# 2  63782900000000  2022-03-14T18:45:34   875413210
# 3  63782900000000  2022-03-14T18:45:34   875413210
# 4  63782900000000  2022-03-14T18:45:35   875413210
# 5  63782900000000  2022-03-15T10:24:37   875413210
# 6  63782900000000  2022-03-15T10:25:04   875413210
# 7  63782900000000  2022-03-15T10:25:40   875413210
# 8  63782900000000  2022-03-15T10:25:51   875413210
# 9  63782900000000  2022-03-15T10:25:53   875413210
#
#                                       ТекстСообщения  ИдСообщения  \
# 0                                                123       1103.0
# 1                                             Отмена       1105.0
# 2  С помощью кнопок под этим сообщением выберите ...       1096.0
# 3  С помощью кнопок под этим сообщением выберите ...       1096.0
# 4  С помощью кнопок под этим сообщением выберите ...       1096.0
# ...

# %%
len(key)
# Out:
# 120690

# %%
data['История кнопки']=key

# %%
data
# Out:
#           МеткаВремени        ДатаСообщения  ИдКонтакта  \
# 0       63782900000000  2022-03-14T18:44:38   875413210
# 1       63782900000000  2022-03-14T18:44:41   875413210
# 2       63782900000000  2022-03-14T18:45:34   875413210
# 3       63782900000000  2022-03-14T18:45:34   875413210
# 4       63782900000000  2022-03-14T18:45:35   875413210
# ...                ...                  ...         ...
# 120685  63818600000000  2023-05-02T11:47:15   960116134
# 120686  63818600000000  2023-05-02T14:20:20   960116134
# 120687  63818600000000  2023-05-02T14:29:45  1362353916
# 120688  63818600000000  2023-05-02T15:36:24   844275005
# 120689  63818600000000  2023-05-02T19:53:17   960116134
#
#                                            ТекстСообщения  ИдСообщения  \
# 0                                                     123       1103.0
# 1                                                  Отмена       1105.0
# 2       С помощью кнопок под этим сообщением выберите ...       1096.0
# ...

# %%
data.to_excel(r'C:\Users\Julaysa\Desktop\statistics.xlsx.xlsx',index=False)

# %%
data.to_csv('',index=True)
